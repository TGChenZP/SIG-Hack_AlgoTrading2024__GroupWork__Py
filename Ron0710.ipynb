# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm
from collections import defaultdict

from statsmodels.regression.linear_model import OLS
from sklearn.metrics import r2_score, accuracy_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def loadPrices(fn):
    global nt, nInst
    df = pd.read_csv(fn, sep='\s+', header=None, index_col=None)
    (nt, nInst) = df.shape
    return (df.values).T

# %% [markdown]
# # Load Data

# %%
prcAll = loadPrices('prices_r1.txt')

NUM_STOCKS = prcAll.shape[0]

# %% [markdown]
# # Build Models

# %%
def get_log_returns(prices):
    # get log_returns
    # put into pandas
    prices_df = pd.DataFrame(prices).T
    # turn into log returns
    log_return_df = prices_df.pct_change().apply(lambda x: np.log(1+x)).shift(-1)

    for ma in [5,10]:
        for stock_i in range(nInst+1):
            log_return_df[f'forward_{ma}_{stock_i}'] = np.log(prices_df[stock_i]/prices_df[stock_i].shift(ma)).shift(-ma)
            log_return_df[f'close_to_close (t-{ma})(t0)_'+str(stock_i)] = np.log(prices_df[stock_i]/prices_df[stock_i].shift(ma))
            
    # for ma in [1, 5]:
    #     for stock_i in range(nInst):
    #         for stock_j in range(stock_i+1, nInst):
    #             log_return_df[f'diff_forward_{ma}_{stock_i}_{stock_j}'] = log_return_df[f'forward_{ma}_{stock_i}'] - log_return_df[f'forward_{ma}_{stock_j}']
    #             log_return_df[f'diff_close_to_close (t-{ma})(t0)_'+str(stock_i)+'_'+str(stock_j)] = log_return_df[f'close_to_close (t-{ma})(t0)_{stock_i}'] - log_return_df[f'close_to_close (t-{ma})(t0)_{stock_j}']

    return log_return_df

# %%
def feature_engineer(prices):
    
    # add market which is the mean of all returns
    prices = np.vstack((prices, prices.mean(axis=0)))

    log_return_df = get_log_returns(prices)
    # feature engineering

    # for stock_id in range(nInst+1):
        # create lags
        # log_return_df['lag1_'+str(stock_id)] = log_return_df[stock_id].shift(1)
        # log_return_df['lag2_'+str(stock_id)] = log_return_df[stock_id].shift(2)
        
        # create MA
        # log_return_df['ma5_'+str(stock_id)] = log_return_df[stock_id].rolling(window=5).mean().shift(1)
        # log_return_df['ma10_'+str(stock_id)] = log_return_df[stock_id].rolling(window=10).mean().shift(1)
        # log_return_df['ma20_'+str(stock_id)] = log_return_df[stock_id].rolling(window=20).mean().shift(1)

    log_return_df.rename(columns={stock_id:str(stock_id) for stock_id in range(nInst+1)}, inplace=True)
        
    
    return log_return_df

# %%
log_return_df = feature_engineer(prcAll)

# %%
TRAIN_LENGTH = 250
TEST_LENGTH = 250
FIRST_TEST_DATE = 250

features = ['close_to_close (t-5)(t0)']
target_column = ''

# %%
def build_multivariate_linear_regression(log_return_df, target_stock, feature_stock, features, test_start_date, train_length, target_column):

    data = log_return_df[[f'{target_column}{target_stock}']+[f'{_}_{target_stock}' for _ in features]+[f'{_}_{feature_stock}' for _ in features]].iloc[test_start_date-train_length:test_start_date]
    if target_stock == feature_stock:
        data = log_return_df[[f'{target_column}{target_stock}']+[f'{_}_{target_stock}' for _ in features]].iloc[test_start_date-train_length:test_start_date]
    data.dropna(inplace=True)

    y = data[f'{target_column}{target_stock}']
    X = data.drop(columns=[f'{target_column}{target_stock}'])
    X = X.assign(const=1)

    # build models
    model = OLS(y, X).fit()

    return model

def inference_multivariate_linear_regression(log_return_df, model, target_stock, feature_stock, features):
    
    X = log_return_df[[f'{_}_{target_stock}' for _ in features]+[f'{_}_{feature_stock}' for _ in features]].iloc[-1:]
    if target_stock == feature_stock:
        X = log_return_df[[f'{_}_{target_stock}' for _ in features]].iloc[-1:]

    X = X.assign(const=1)
    
    pred_t1 = model.predict(X).values[0]

    return pred_t1

def predict_train_multivariate(log_return_df, model, target_stock, feature_stock, features, test_start_date, train_length, target_column):
    
    data = log_return_df[[f'{target_column}{target_stock}']+[f'{_}_{target_stock}' for _ in features]+[f'{_}_{feature_stock}' for _ in features]].iloc[test_start_date-train_length:test_start_date]
    if target_stock == feature_stock:
        data = log_return_df[[f'{target_column}{target_stock}']+[f'{_}_{target_stock}' for _ in features]].iloc[test_start_date-train_length:test_start_date]
    data.dropna(inplace=True)

    y = data[f'{target_column}{target_stock}']
    X = data.drop(columns=[f'{target_column}{target_stock}'])
    X = X.assign(const=1)

    y_pred = model.predict(X)
    
    return y, y_pred

# %%
# good_model_dict = defaultdict(dict)
# model_accuracy_dict = defaultdict(dict)
# model_features_dict = defaultdict(dict)

# for i in tqdm(range(NUM_STOCKS)):
#     for j in range(NUM_STOCKS+1):

#         ma_model = build_multivariate_linear_regression(log_return_df, i, j, features, FIRST_TEST_DATE, TRAIN_LENGTH, target_column)
#         ma_y, ma_pred = predict_train_multivariate(log_return_df, ma_model, i, j, features, FIRST_TEST_DATE, TRAIN_LENGTH, target_column)

#         if abs(ma_model.tvalues.values[0]) >= 2 or abs(ma_model.tvalues.values[len(features)]//2) >= 2:
#             good_model_dict[i][j] = ma_model
#             model_features_dict[i][j] = features
#             model_accuracy_dict[i][j] = accuracy_score(np.sign(ma_y), np.sign(ma_pred))

# final_model = defaultdict(dict)

# for stock_i in model_accuracy_dict:
#     top_10 = sorted(model_accuracy_dict[stock_i].items(), key=lambda x: x[1], reverse=True)
#     for stock_j, score in top_10:

#         if stock_j in good_model_dict[stock_i]: # Todo: in future take average, or take average of votes?
#             final_model[stock_i][stock_j] = good_model_dict[stock_i][stock_j]

# %%
# for stock_i in final_model:
#     print(stock_i, final_model[stock_i].keys())

# %% [markdown]
# # Backtest

# %% [markdown]
# ## Define Strategy

# %%
def build_models_for_this_period(log_return_df, test_start_date, features, train_length, target_column):

    good_model_dict = defaultdict(dict)
    model_accuracy_dict = defaultdict(dict)
    model_features_dict = defaultdict(dict)

    for i in range(NUM_STOCKS):
        for j in range(NUM_STOCKS+1):
            
            ma_model = build_multivariate_linear_regression(log_return_df, i, j, features, test_start_date, train_length, target_column)
            ma_y, ma_pred = predict_train_multivariate(log_return_df, ma_model, i, j, features, test_start_date, train_length, target_column)

            if abs(ma_model.tvalues.values[0]) >= 2 or abs(ma_model.tvalues.values[len(features)]//2) >= 2:
                good_model_dict[i][j] = ma_model
                model_features_dict[i][j] = features
                model_accuracy_dict[i][j] = accuracy_score(np.sign(ma_y), np.sign(ma_pred))

    final_model_dict = defaultdict(dict)

    for stock_i in model_accuracy_dict:
        top_10 = sorted(model_accuracy_dict[stock_i].items(), key=lambda x: x[1], reverse=True)
        # need to keep top_10 even
        # if len(top_10) % 2 != 0:
        #     top_10 = top_10[:-1]
        for stock_j, score in top_10:
            
            if stock_j in good_model_dict[stock_i]: # Todo: in future take average, or take average of votes?
                final_model_dict[stock_i][stock_j] = good_model_dict[stock_i][stock_j]  

    return final_model_dict, model_features_dict

# %%
def exp_growth(x, a=500, b= 0.00013863, c=0):
    return a * np.exp(b * x) + c

# %%
def get_suspension_signals(log_return_df, prcSoFar, stock_i, START_DATE, SUSPENSION_LOOKBACK, signals):
    lookback_returns = log_return_df[str(stock_i)].iloc[-SUSPENSION_LOOKBACK-1:-1].tolist() # get last 10 days of return
    # get 10 day sign flip
    last_n_return_sign_changes = sum(np.sign(lookback_returns[i]) != np.sign(lookback_returns[i-1]) for i in range(1, len(lookback_returns)))

    # get accuracy
    # get number of signal different sign to last 10 days
    lookback_signals = signals[stock_i, prcSoFar.shape[1]-START_DATE-SUSPENSION_LOOKBACK:prcSoFar.shape[1]-START_DATE]
    wrong_sign = sum(lookback_signals[i] != 0 and np.sign(lookback_signals[i]) != np.sign(lookback_returns[i]) for i in range(len(lookback_signals)))

    return last_n_return_sign_changes, wrong_sign

def apply_suspension(last_n_return_sign_changes, wrong_sign, SUSPENSION_LOOKBACK, SUSPENSION_DAYS, SIGN_CHANGE_THRESHOLD, WRONG_SIGN_THRESHOLD, suspension_days, suspension_activated, stock_i, START_DATE, prcSoFar):
    
    if last_n_return_sign_changes/SUSPENSION_LOOKBACK >= SIGN_CHANGE_THRESHOLD or wrong_sign/SUSPENSION_LOOKBACK >= WRONG_SIGN_THRESHOLD:
        suspension_days[stock_i] = SUSPENSION_DAYS # ban for 3 days
        suspension_activated[stock_i, prcSoFar.shape[1]-START_DATE] = 1
        
    return suspension_days, suspension_activated

def get_stop_loss_signals(currentPos, log_return_df, stock_i, STOP_LOSS_LOOKBACK, final_model_dict_5, model_features_dict_5):
    # get sum of sign of last 2 days
    stop_loss_lookback_return = np.sum(np.sign(log_return_df[str(stock_i)].iloc[-STOP_LOSS_LOOKBACK-1:-1].tolist())) 

    # get current position sign
    stock_i_curr_pos_sign = np.sign(currentPos[stock_i])

    # get 5 days prediction
    stock_i_predictions_list_5 = []
    for stock_j in final_model_dict_5[stock_i]:
        stock_i_predictions_list_5.append(inference_multivariate_linear_regression(log_return_df,
                                final_model_dict_5[stock_i][stock_j],
                                stock_i,
                                stock_j,
                                model_features_dict_5[stock_i][stock_j]))
    
    stock_i_prediction_5 = np.sign(np.sum([np.sign(x) for x in stock_i_predictions_list_5]))

    return stop_loss_lookback_return, stock_i_curr_pos_sign, stock_i_prediction_5

def apply_stop_loss(stop_loss_lookback_return, stock_i_prediction_5, stock_i_curr_pos_sign, STOP_LOSS_LOOKBACK, STOP_LOSS_SIZE_FACTOR, currentPos, prcSoFar, START_DATE, stop_loss_activated, stock_i):
    stop_loss_today = False

    # if stop_loss_lookback_return == -STOP_LOSS_LOOKBACK and stock_i_prediction_5 == -1 and stock_i_curr_pos_sign == 1:
    if stock_i_prediction_5 == -1 and stock_i_curr_pos_sign == 1:
        currentPos[stock_i] -= STOP_LOSS_SIZE_FACTOR * exp_growth(abs(currentPos[stock_i]*prcSoFar[stock_i, -1]))/prcSoFar[stock_i, -1]
        stop_loss_today = True
        stop_loss_activated[stock_i, prcSoFar.shape[1]-START_DATE] = 1
    # elif stop_loss_lookback_return == STOP_LOSS_LOOKBACK and stock_i_prediction_5 == 1 and stock_i_curr_pos_sign == -1:
    elif stock_i_prediction_5 == 1 and stock_i_curr_pos_sign == -1:
        currentPos[stock_i] += STOP_LOSS_SIZE_FACTOR * exp_growth(abs(currentPos[stock_i]*prcSoFar[stock_i, -1]))/prcSoFar[stock_i, -1]
        stop_loss_today = True
        stop_loss_activated[stock_i, prcSoFar.shape[1]-START_DATE] = 1
    
    return currentPos, stop_loss_today, stop_loss_activated

def get_signals(log_return_df, final_model_dict, stock_i, model_features_dict, signals, prcSoFar, START_DATE):
    
    stock_i_predictions_list = []
    for stock_j in final_model_dict[stock_i]:
        stock_i_predictions_list.append(inference_multivariate_linear_regression(log_return_df,
                                final_model_dict[stock_i][stock_j],
                                stock_i,
                                stock_j,
                                model_features_dict[stock_i][stock_j]))

        
    stock_i_prediction = np.sign(np.sum([np.sign(x) for x in stock_i_predictions_list]))

    signals[stock_i, prcSoFar.shape[1]-START_DATE] = stock_i_prediction

    return stock_i_prediction, signals

def update_position_for_stock(stock_i_prediction, currentPos, stock_i, prcSoFar):
    if stock_i_prediction > 0:
        if currentPos[stock_i] > 0:
            currentPos[stock_i] += exp_growth(10000-abs(currentPos[stock_i]*prcSoFar[stock_i, -1]))/prcSoFar[stock_i, -1]
        else:
            currentPos[stock_i] += exp_growth(abs(currentPos[stock_i]*prcSoFar[stock_i, -1]))/prcSoFar[stock_i, -1]
    elif stock_i_prediction < -0:
        if currentPos[stock_i] < 0:
            currentPos[stock_i] -= exp_growth(10000-abs(currentPos[stock_i]*prcSoFar[stock_i, -1]))/prcSoFar[stock_i, -1]
        else:
            currentPos[stock_i] -= exp_growth(abs(currentPos[stock_i]*prcSoFar[stock_i, -1]))/prcSoFar[stock_i, -1]
    
    return currentPos

# %%
def getMyPosition(prcSoFar):
    
    global currentPos, \
            final_model_dict, \
            model_features_dict, \
            test_start_date, \
            signals, \
            suspension_days, \
            stop_loss_activated, \
            suspension_activated, \
            final_model_dict_5, \
            model_features_dict_5
    
    # last day don't make any new positions
    if prcSoFar.shape[1] == START_DATE+250: 
        return currentPos

    # feature engineered data
    log_return_df = feature_engineer(prcSoFar)

    # first day train the models
    if prcSoFar.shape[1] == START_DATE:

        currentPos = np.zeros(nInst)

        # get structures for reporting
        signals = np.zeros([50, 251])
        suspension_activated = np.zeros([50, 251])
        stop_loss_activated = np.zeros([50, 251])

        # structure to record days of suspension for each model 
        suspension_days = defaultdict(int)

        # get the first date for test period
        test_start_date = prcSoFar.shape[1]

        # train models
        final_model_dict, model_features_dict = build_models_for_this_period(log_return_df, test_start_date, features, TRAIN_LENGTH, TARGET_COLUMN)
        final_model_dict_5, model_features_dict_5 = build_models_for_this_period(log_return_df, test_start_date, features, TRAIN_LENGTH, FIVE_DAY_TARGET_COLUMN)

    for stock_i in final_model_dict:

        stop_loss_today = False

        if prcSoFar.shape[1] >= START_DATE + BUILD_PERIOD: # skip first couple of days
            
            # MODEL SUSPENSION
            last_n_return_sign_changes, wrong_sign = get_suspension_signals(log_return_df, prcSoFar, stock_i, START_DATE, SUSPENSION_LOOKBACK, signals)
            suspension_days, suspension_activated = apply_suspension(last_n_return_sign_changes, wrong_sign, SUSPENSION_LOOKBACK, SUSPENSION_DAYS, SIGN_CHANGE_THRESHOLD, WRONG_SIGN_THRESHOLD, suspension_days, suspension_activated, stock_i, START_DATE, prcSoFar)

            # STOP LOSS
            stop_loss_lookback_return, stock_i_curr_pos_sign, stock_i_prediction_5 = get_stop_loss_signals(currentPos, log_return_df, stock_i, STOP_LOSS_LOOKBACK, final_model_dict_5, model_features_dict_5)
            currentPos, stop_loss_today, stop_loss_activated = apply_stop_loss(stop_loss_lookback_return, stock_i_prediction_5, stock_i_curr_pos_sign, STOP_LOSS_LOOKBACK, STOP_LOSS_SIZE_FACTOR, currentPos, prcSoFar, START_DATE, stop_loss_activated, stock_i)

        # OPEN POSITION WITH MODEL
        stock_i_prediction, signals = get_signals(log_return_df, final_model_dict, stock_i, model_features_dict, signals, prcSoFar, START_DATE)

        # consider suspension and stop loss, then adjust position
        if suspension_days[stock_i] > 0: # model suspended
            suspension_days[stock_i] -= 1
        elif stop_loss_today: # stop loss, don't use model to open position
            pass 
        else: # update the position
            currentPos = update_position_for_stock(stock_i_prediction, currentPos, stock_i, prcSoFar)

        # clip to 10k
        currentPos[stock_i] = np.clip(currentPos[stock_i], -10000/prcSoFar[stock_i, -1], 10000/prcSoFar[stock_i, -1])

    return currentPos

# %%
def get_audit_table(signals, stop_loss_activated, suspension_activated, positions, todayPL_array, returns, commission_array, prcAll, final_model_dict, const):
    df_rows = []
    for STOCK in final_model_dict:

        for i in range(251):
            df_rows.append({
                'Signal': int(np.sign(signals[STOCK][i])),
                'Stop Loss Activated': int(stop_loss_activated[STOCK][i]),
                'Suspension Activated': int(suspension_activated[STOCK][i]),
                'Price': prcAll[STOCK][i+const],
                'Price x Positions': prcAll[STOCK][i+const] * positions[STOCK][i],
                'Change in positions': np.round(positions[STOCK][i]-positions[STOCK][i-1], 1) if i != 0 else np.round(positions[STOCK][i], 1),
                'Price x Change in position': prcAll[STOCK][i+const] * np.round(positions[STOCK][i]-positions[STOCK][i-1], 1) if i != 0 else prcAll[STOCK][i+const]*np.round(positions[STOCK][i], 1), 
                'Positions': np.round(positions[STOCK][i], 1),
                'PnL': np.round(todayPL_array[STOCK][i], 2),
                'PnL + Commission': np.round(todayPL_array[STOCK][i]+commission_array[STOCK][i], 2),
                'Returns': np.round(returns[STOCK][i], 4),
                'Commission': np.round(commission_array[STOCK][i], 2),
                'Stock': STOCK,
                'Day': i+const+1})
                # 'audit_PnL': returns[STOCK][i] * positions[STOCK][i] * prcAll[STOCK][i+249]})

    audit_df = pd.DataFrame(df_rows)
    return audit_df

# %% [markdown]
# ## Run

# %%
TRAIN_LENGTH = 250
TEST_LENGTH = 250

# Hyperparmeters
SUSPENSION_LOOKBACK = 7
WRONG_SIGN_THRESHOLD = 0.5
SIGN_CHANGE_THRESHOLD = 0.75
SUSPENSION_DAYS = 3
STOP_LOSS_LOOKBACK = 2
STOP_LOSS_SIZE_FACTOR = .25

BUILD_PERIOD = 10

features = ['close_to_close (t-5)(t0)']
TARGET_COLUMN = ''
FIVE_DAY_TARGET_COLUMN = 'forward_10_'

# %%
START_DATE = 250

positions = np.zeros([50, 251])
returns = np.zeros([50, 251])

values_array = np.zeros([50, 251])
cash_array = np.zeros([50, 251])
commission_array = np.zeros([50, 251])
todayPL_array = np.zeros([50, 251])

commRate = 0.0010
dlrPosLimit = 10000

nInst = 50

def calcPL(prcHist):
    global pll
    cash = 0
    curPos = np.zeros(nInst)
    totDVolume = 0
    totDVolumeSignal = 0
    totDVolumeRandom = 0
    value = 0
    todayPLL = []
    (_, nt) = prcHist.shape
    for t in range(250, 501): # t will go from 250 to 500 (251 numbers)
        prcHistSoFar = prcHist[:, :t] # t=250 => will go from i.e. day 0 to day 249 (250 days). day = t-1; t = 500: don't trade - only lose brockerage
        newPosOrig = getMyPosition(prcHistSoFar) # day 250 train, then make positions for 251...
        curPrices = prcHistSoFar[:, -1]
        posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
        newPos = np.clip(newPosOrig, -posLimits, posLimits) # t0 make new positions
        deltaPos = newPos - curPos # t0 change position
        
        positions[:, prcHistSoFar.shape[1]-START_DATE] = newPos # record position
        
        dvolumes = curPrices * np.abs(deltaPos) # t0 transaction volumes
        dvolume = np.sum(dvolumes)
        totDVolume += dvolume 
        comm = dvolume * commRate # t0 commission
        cash -= curPrices.dot(deltaPos) + comm  # t0 change in cash: long/short stocks and commission

        commission_array[:, prcHistSoFar.shape[1]-START_DATE] = curPrices*np.abs(deltaPos) * commRate

        cash_array[:, prcHistSoFar.shape[1]-START_DATE] = np.zeros([50]) - curPrices * deltaPos - np.abs(deltaPos) * curPrices * commRate if t == START_DATE \
              else cash_array[:, prcHistSoFar.shape[1]-START_DATE-1] - curPrices * deltaPos - np.abs(deltaPos) * curPrices * commRate

        curPos = np.array(newPos) 
        posValue = curPos.dot(curPrices) # value of stocks = what was earned from t-1's positions + value of t0 stocks. (balances out part of the cash change)
        todayPL = cash + posValue - value # today's profit/loss: cash + value of stocks - value of stocks at t-1 
        
        if t != START_DATE+250:
            returns[:, prcHistSoFar.shape[1]-START_DATE] = prcHist[:, t] / prcHist[:, t-1] - 1
            todayPL_array[:, prcHistSoFar.shape[1]-START_DATE] = cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices if t == START_DATE \
                else cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices - values_array[:, prcHistSoFar.shape[1]-START_DATE-1]

        todayPLL.append(todayPL) 
        value = cash + posValue

        values_array[:, prcHistSoFar.shape[1]-START_DATE] = cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices

        ret = 0.0
        if (totDVolume > 0):
            ret = value / totDVolume
        print("Day %d value: %.2lf todayPL: $%.2lf $-traded: %.0lf return: %.5lf" %
              (t, value, todayPL, totDVolume, ret))
    pll = np.array(todayPLL)
    (plmu, plstd) = (np.mean(pll), np.std(pll))
    annSharpe = 0.0
    if (plstd > 0):
        annSharpe = np.sqrt(250) * plmu / plstd
    return (plmu, ret, plstd, annSharpe, totDVolume)


(meanpl, ret, plstd, sharpe, dvol) = calcPL(prcAll)
score = meanpl - 0.1*plstd
print("=====")
print("mean(PL): %.1lf" % meanpl)
print("return: %.5lf" % ret)
print("StdDev(PL): %.2lf" % plstd)
print("annSharpe(PL): %.2lf " % sharpe)
print("totDvolume: %.0lf " % dvol)
print("Score: %.2lf" % score)
# Out:
# Day 250 value: -13.50 todayPL: $-13.50 $-traded: 13500 return: -0.00100
# Day 251 value: -71.50 todayPL: $-58.00 $-traded: 60063 return: -0.00119
# Day 252 value: -71.01 todayPL: $0.49 $-traded: 96788 return: -0.00073
# Day 253 value: -201.52 todayPL: $-130.52 $-traded: 127177 return: -0.00158
# Day 254 value: -455.92 todayPL: $-254.40 $-traded: 155444 return: -0.00293
# Day 255 value: -558.03 todayPL: $-102.11 $-traded: 180878 return: -0.00309
# Day 256 value: -474.02 todayPL: $84.01 $-traded: 205381 return: -0.00231
# Day 257 value: -541.00 todayPL: $-66.99 $-traded: 229660 return: -0.00236
# Day 258 value: -824.90 todayPL: $-283.90 $-traded: 250235 return: -0.00330
# Day 259 value: -703.50 todayPL: $121.40 $-traded: 276094 return: -0.00255
# Day 260 value: -831.44 todayPL: $-127.95 $-traded: 280475 return: -0.00296
# Day 261 value: -432.89 todayPL: $398.55 $-traded: 285601 return: -0.00152
# Day 262 value: -367.29 todayPL: $65.61 $-traded: 291463 return: -0.00126
# Day 263 value: -307.12 todayPL: $60.17 $-traded: 296251 return: -0.00104
# Day 264 value: -232.52 todayPL: $74.60 $-traded: 300905 return: -0.00077
# Day 265 value: 53.09 todayPL: $285.61 $-traded: 308278 return: 0.00017
# Day 266 value: 188.64 todayPL: $135.55 $-traded: 316164 return: 0.00060
# Day 267 value: 128.12 todayPL: $-60.53 $-traded: 321633 return: 0.00040
# Day 268 value: 213.30 todayPL: $85.18 $-traded: 330453 return: 0.00065
# Day 269 value: 675.73 todayPL: $462.43 $-traded: 336364 return: 0.00201
# Day 270 value: 1110.62 todayPL: $434.89 $-traded: 339590 return: 0.00327
# Day 271 value: 1135.65 todayPL: $25.03 $-traded: 347640 return: 0.00327
# Day 272 value: 1190.31 todayPL: $54.66 $-traded: 355010 return: 0.00335
# Day 273 value: 1087.24 todayPL: $-103.07 $-traded: 362771 return: 0.00300
# Day 274 value: 951.89 todayPL: $-135.36 $-traded: 370205 return: 0.00257
# Day 275 value: 1348.77 todayPL: $396.88 $-traded: 375036 return: 0.00360
# Day 276 value: 1364.45 todayPL: $15.69 $-traded: 381307 return: 0.00358
# Day 277 value: 1411.98 todayPL: $47.52 $-traded: 394009 return: 0.00358
# Day 278 value: 1560.12 todayPL: $148.14 $-traded: 401705 return: 0.00388
# Day 279 value: 1628.55 todayPL: $68.43 $-traded: 408728 return: 0.00398
# Day 280 value: 1828.07 todayPL: $199.52 $-traded: 414936 return: 0.00441
# Day 281 value: 2172.34 todayPL: $344.27 $-traded: 422506 return: 0.00514
# Day 282 value: 2164.99 todayPL: $-7.35 $-traded: 432815 return: 0.00500
# Day 283 value: 2289.34 todayPL: $124.35 $-traded: 445411 return: 0.00514
# Day 284 value: 2507.18 todayPL: $217.84 $-traded: 454119 return: 0.00552
# Day 285 value: 2148.41 todayPL: $-358.77 $-traded: 460364 return: 0.00467
# Day 286 value: 2114.89 todayPL: $-33.52 $-traded: 469076 return: 0.00451
# Day 287 value: 2268.29 todayPL: $153.40 $-traded: 474969 return: 0.00478
# Day 288 value: 1865.27 todayPL: $-403.02 $-traded: 481597 return: 0.00387
# Day 289 value: 1512.80 todayPL: $-352.47 $-traded: 488399 return: 0.00310
# Day 290 value: 1399.44 todayPL: $-113.36 $-traded: 493197 return: 0.00284
# Day 291 value: 1441.66 todayPL: $42.21 $-traded: 499194 return: 0.00289
# Day 292 value: 1195.19 todayPL: $-246.47 $-traded: 505600 return: 0.00236
# Day 293 value: 1301.61 todayPL: $106.42 $-traded: 511531 return: 0.00254
# Day 294 value: 1128.59 todayPL: $-173.02 $-traded: 516909 return: 0.00218
# Day 295 value: 1060.18 todayPL: $-68.41 $-traded: 520852 return: 0.00204
# Day 296 value: 1174.89 todayPL: $114.71 $-traded: 523657 return: 0.00224
# Day 297 value: 1094.58 todayPL: $-80.31 $-traded: 528186 return: 0.00207
# Day 298 value: 966.51 todayPL: $-128.07 $-traded: 531663 return: 0.00182
# Day 299 value: 492.62 todayPL: $-473.89 $-traded: 536814 return: 0.00092
# Day 300 value: 356.18 todayPL: $-136.44 $-traded: 544687 return: 0.00065
# Day 301 value: 2.60 todayPL: $-353.58 $-traded: 550063 return: 0.00000
# Day 302 value: 185.84 todayPL: $183.24 $-traded: 555291 return: 0.00033
# Day 303 value: 121.09 todayPL: $-64.75 $-traded: 558964 return: 0.00022
# Day 304 value: 150.03 todayPL: $28.94 $-traded: 565213 return: 0.00027
# Day 305 value: 276.46 todayPL: $126.43 $-traded: 569341 return: 0.00049
# Day 306 value: 233.18 todayPL: $-43.28 $-traded: 575830 return: 0.00040
# Day 307 value: 728.28 todayPL: $495.10 $-traded: 581378 return: 0.00125
# Day 308 value: 723.10 todayPL: $-5.19 $-traded: 586488 return: 0.00123
# Day 309 value: 698.93 todayPL: $-24.17 $-traded: 596160 return: 0.00117
# Day 310 value: 706.01 todayPL: $7.09 $-traded: 604795 return: 0.00117
# Day 311 value: 1001.72 todayPL: $295.71 $-traded: 610719 return: 0.00164
# Day 312 value: 856.65 todayPL: $-145.07 $-traded: 617787 return: 0.00139
# Day 313 value: 1156.99 todayPL: $300.34 $-traded: 625398 return: 0.00185
# Day 314 value: 1259.82 todayPL: $102.82 $-traded: 628612 return: 0.00200
# Day 315 value: 1330.61 todayPL: $70.80 $-traded: 641466 return: 0.00207
# Day 316 value: 1371.44 todayPL: $40.83 $-traded: 650838 return: 0.00211
# Day 317 value: 1436.41 todayPL: $64.98 $-traded: 659459 return: 0.00218
# Day 318 value: 1377.11 todayPL: $-59.30 $-traded: 670614 return: 0.00205
# Day 319 value: 1452.73 todayPL: $75.62 $-traded: 681487 return: 0.00213
# Day 320 value: 1200.26 todayPL: $-252.47 $-traded: 690944 return: 0.00174
# Day 321 value: 1233.91 todayPL: $33.64 $-traded: 699475 return: 0.00176
# Day 322 value: 1370.11 todayPL: $136.21 $-traded: 706375 return: 0.00194
# Day 323 value: 1646.61 todayPL: $276.50 $-traded: 713901 return: 0.00231
# Day 324 value: 1703.56 todayPL: $56.94 $-traded: 718599 return: 0.00237
# Day 325 value: 1545.67 todayPL: $-157.89 $-traded: 722251 return: 0.00214
# Day 326 value: 1512.03 todayPL: $-33.64 $-traded: 729428 return: 0.00207
# Day 327 value: 1627.96 todayPL: $115.93 $-traded: 738158 return: 0.00221
# Day 328 value: 1957.63 todayPL: $329.66 $-traded: 746158 return: 0.00262
# Day 329 value: 2354.94 todayPL: $397.31 $-traded: 753966 return: 0.00312
# Day 330 value: 2519.22 todayPL: $164.28 $-traded: 765475 return: 0.00329
# Day 331 value: 3173.81 todayPL: $654.59 $-traded: 774152 return: 0.00410
# Day 332 value: 3344.54 todayPL: $170.74 $-traded: 782599 return: 0.00427
# Day 333 value: 3295.78 todayPL: $-48.76 $-traded: 791141 return: 0.00417
# Day 334 value: 3199.52 todayPL: $-96.26 $-traded: 801088 return: 0.00399
# Day 335 value: 3364.51 todayPL: $165.00 $-traded: 808480 return: 0.00416
# Day 336 value: 3150.96 todayPL: $-213.55 $-traded: 816747 return: 0.00386
# Day 337 value: 3285.83 todayPL: $134.86 $-traded: 826143 return: 0.00398
# Day 338 value: 3650.53 todayPL: $364.70 $-traded: 836515 return: 0.00436
# Day 339 value: 3821.26 todayPL: $170.74 $-traded: 844963 return: 0.00452
# Day 340 value: 3976.23 todayPL: $154.97 $-traded: 852153 return: 0.00467
# Day 341 value: 4142.02 todayPL: $165.80 $-traded: 857556 return: 0.00483
# Day 342 value: 4019.45 todayPL: $-122.58 $-traded: 867609 return: 0.00463
# Day 343 value: 4464.10 todayPL: $444.65 $-traded: 876773 return: 0.00509
# Day 344 value: 5230.87 todayPL: $766.77 $-traded: 884403 return: 0.00591
# Day 345 value: 4713.98 todayPL: $-516.89 $-traded: 890595 return: 0.00529
# Day 346 value: 4569.37 todayPL: $-144.60 $-traded: 896324 return: 0.00510
# Day 347 value: 4563.97 todayPL: $-5.40 $-traded: 902377 return: 0.00506
# Day 348 value: 4424.24 todayPL: $-139.73 $-traded: 904906 return: 0.00489
# Day 349 value: 4263.27 todayPL: $-160.98 $-traded: 911718 return: 0.00468
# Day 350 value: 4618.28 todayPL: $355.01 $-traded: 922540 return: 0.00501
# Day 351 value: 4827.42 todayPL: $209.14 $-traded: 930197 return: 0.00519
# Day 352 value: 4588.98 todayPL: $-238.45 $-traded: 933429 return: 0.00492
# Day 353 value: 4678.20 todayPL: $89.22 $-traded: 937567 return: 0.00499
# Day 354 value: 4529.34 todayPL: $-148.86 $-traded: 940758 return: 0.00481
# Day 355 value: 4441.68 todayPL: $-87.66 $-traded: 945622 return: 0.00470
# Day 356 value: 4377.63 todayPL: $-64.06 $-traded: 950571 return: 0.00461
# Day 357 value: 4729.67 todayPL: $352.05 $-traded: 953607 return: 0.00496
# Day 358 value: 4455.19 todayPL: $-274.48 $-traded: 960760 return: 0.00464
# Day 359 value: 4154.41 todayPL: $-300.78 $-traded: 965502 return: 0.00430
# Day 360 value: 4339.76 todayPL: $185.35 $-traded: 973242 return: 0.00446
# Day 361 value: 4113.84 todayPL: $-225.92 $-traded: 979710 return: 0.00420
# Day 362 value: 4001.05 todayPL: $-112.79 $-traded: 990894 return: 0.00404
# Day 363 value: 3923.32 todayPL: $-77.73 $-traded: 997624 return: 0.00393
# Day 364 value: 3817.49 todayPL: $-105.83 $-traded: 1004101 return: 0.00380
# Day 365 value: 3903.01 todayPL: $85.52 $-traded: 1010536 return: 0.00386
# Day 366 value: 3824.60 todayPL: $-78.41 $-traded: 1015633 return: 0.00377
# Day 367 value: 3912.00 todayPL: $87.40 $-traded: 1022048 return: 0.00383
# Day 368 value: 4068.01 todayPL: $156.01 $-traded: 1029406 return: 0.00395
# Day 369 value: 3801.22 todayPL: $-266.79 $-traded: 1037368 return: 0.00366
# Day 370 value: 3767.43 todayPL: $-33.78 $-traded: 1044422 return: 0.00361
# Day 371 value: 3516.19 todayPL: $-251.24 $-traded: 1048668 return: 0.00335
# Day 372 value: 3655.49 todayPL: $139.30 $-traded: 1057110 return: 0.00346
# Day 373 value: 3432.10 todayPL: $-223.39 $-traded: 1064443 return: 0.00322
# Day 374 value: 3098.35 todayPL: $-333.75 $-traded: 1070553 return: 0.00289
# Day 375 value: 3099.79 todayPL: $1.44 $-traded: 1077401 return: 0.00288
# Day 376 value: 3252.46 todayPL: $152.67 $-traded: 1084226 return: 0.00300
# Day 377 value: 3049.81 todayPL: $-202.64 $-traded: 1091574 return: 0.00279
# Day 378 value: 2851.31 todayPL: $-198.51 $-traded: 1100624 return: 0.00259
# Day 379 value: 3028.16 todayPL: $176.85 $-traded: 1106309 return: 0.00274
# Day 380 value: 2990.96 todayPL: $-37.21 $-traded: 1114838 return: 0.00268
# Day 381 value: 3024.41 todayPL: $33.45 $-traded: 1123672 return: 0.00269
# Day 382 value: 3040.57 todayPL: $16.16 $-traded: 1129646 return: 0.00269
# Day 383 value: 3199.70 todayPL: $159.13 $-traded: 1138244 return: 0.00281
# Day 384 value: 3299.60 todayPL: $99.90 $-traded: 1150841 return: 0.00287
# Day 385 value: 3514.77 todayPL: $215.16 $-traded: 1158879 return: 0.00303
# Day 386 value: 3628.68 todayPL: $113.91 $-traded: 1168313 return: 0.00311
# Day 387 value: 4040.13 todayPL: $411.45 $-traded: 1178878 return: 0.00343
# Day 388 value: 4286.34 todayPL: $246.21 $-traded: 1186688 return: 0.00361
# Day 389 value: 4570.24 todayPL: $283.90 $-traded: 1196561 return: 0.00382
# Day 390 value: 4679.16 todayPL: $108.92 $-traded: 1204802 return: 0.00388
# Day 391 value: 4787.06 todayPL: $107.90 $-traded: 1213270 return: 0.00395
# Day 392 value: 4933.43 todayPL: $146.38 $-traded: 1221055 return: 0.00404
# Day 393 value: 4687.44 todayPL: $-246.00 $-traded: 1227259 return: 0.00382
# Day 394 value: 4748.07 todayPL: $60.63 $-traded: 1240924 return: 0.00383
# Day 395 value: 5011.26 todayPL: $263.18 $-traded: 1248706 return: 0.00401
# Day 396 value: 4841.63 todayPL: $-169.63 $-traded: 1256564 return: 0.00385
# Day 397 value: 4524.56 todayPL: $-317.08 $-traded: 1264179 return: 0.00358
# Day 398 value: 4570.83 todayPL: $46.28 $-traded: 1274394 return: 0.00359
# Day 399 value: 4044.13 todayPL: $-526.70 $-traded: 1281718 return: 0.00316
# Day 400 value: 4591.52 todayPL: $547.39 $-traded: 1292766 return: 0.00355
# Day 401 value: 4625.44 todayPL: $33.93 $-traded: 1302098 return: 0.00355
# Day 402 value: 4490.68 todayPL: $-134.76 $-traded: 1309429 return: 0.00343
# Day 403 value: 4684.04 todayPL: $193.36 $-traded: 1319647 return: 0.00355
# Day 404 value: 4475.23 todayPL: $-208.80 $-traded: 1328700 return: 0.00337
# Day 405 value: 4566.64 todayPL: $91.41 $-traded: 1333642 return: 0.00342
# Day 406 value: 4437.75 todayPL: $-128.89 $-traded: 1339948 return: 0.00331
# Day 407 value: 4632.66 todayPL: $194.91 $-traded: 1344901 return: 0.00344
# Day 408 value: 4241.36 todayPL: $-391.30 $-traded: 1349167 return: 0.00314
# Day 409 value: 4338.79 todayPL: $97.43 $-traded: 1357799 return: 0.00320
# Day 410 value: 4800.90 todayPL: $462.11 $-traded: 1367250 return: 0.00351
# Day 411 value: 4975.94 todayPL: $175.04 $-traded: 1378143 return: 0.00361
# Day 412 value: 4861.10 todayPL: $-114.84 $-traded: 1390993 return: 0.00349
# Day 413 value: 4842.84 todayPL: $-18.26 $-traded: 1399373 return: 0.00346
# Day 414 value: 4485.49 todayPL: $-357.35 $-traded: 1408914 return: 0.00318
# Day 415 value: 4389.01 todayPL: $-96.48 $-traded: 1416002 return: 0.00310
# Day 416 value: 4381.85 todayPL: $-7.16 $-traded: 1421463 return: 0.00308
# Day 417 value: 4197.61 todayPL: $-184.23 $-traded: 1427926 return: 0.00294
# Day 418 value: 3752.69 todayPL: $-444.93 $-traded: 1432984 return: 0.00262
# Day 419 value: 3890.19 todayPL: $137.51 $-traded: 1437758 return: 0.00271
# Day 420 value: 3905.78 todayPL: $15.59 $-traded: 1440709 return: 0.00271
# Day 421 value: 4020.65 todayPL: $114.88 $-traded: 1446096 return: 0.00278
# Day 422 value: 3961.70 todayPL: $-58.95 $-traded: 1450614 return: 0.00273
# Day 423 value: 3964.46 todayPL: $2.76 $-traded: 1455113 return: 0.00272
# Day 424 value: 3928.08 todayPL: $-36.37 $-traded: 1459968 return: 0.00269
# Day 425 value: 3658.96 todayPL: $-269.13 $-traded: 1468984 return: 0.00249
# Day 426 value: 3839.41 todayPL: $180.46 $-traded: 1479356 return: 0.00260
# Day 427 value: 4473.65 todayPL: $634.23 $-traded: 1486201 return: 0.00301
# Day 428 value: 4588.90 todayPL: $115.25 $-traded: 1491210 return: 0.00308
# Day 429 value: 4779.19 todayPL: $190.30 $-traded: 1496326 return: 0.00319
# Day 430 value: 5092.53 todayPL: $313.33 $-traded: 1501689 return: 0.00339
# Day 431 value: 5113.09 todayPL: $20.56 $-traded: 1506774 return: 0.00339
# Day 432 value: 5129.82 todayPL: $16.73 $-traded: 1514138 return: 0.00339
# Day 433 value: 5310.02 todayPL: $180.20 $-traded: 1519026 return: 0.00350
# Day 434 value: 5162.93 todayPL: $-147.09 $-traded: 1521104 return: 0.00339
# Day 435 value: 5206.79 todayPL: $43.87 $-traded: 1528060 return: 0.00341
# Day 436 value: 5113.24 todayPL: $-93.55 $-traded: 1538017 return: 0.00332
# Day 437 value: 5075.81 todayPL: $-37.43 $-traded: 1545442 return: 0.00328
# Day 438 value: 5171.15 todayPL: $95.34 $-traded: 1552845 return: 0.00333
# Day 439 value: 5039.59 todayPL: $-131.56 $-traded: 1561437 return: 0.00323
# Day 440 value: 5404.12 todayPL: $364.53 $-traded: 1567905 return: 0.00345
# Day 441 value: 5499.34 todayPL: $95.21 $-traded: 1576436 return: 0.00349
# Day 442 value: 5399.97 todayPL: $-99.37 $-traded: 1581673 return: 0.00341
# Day 443 value: 5735.45 todayPL: $335.48 $-traded: 1587768 return: 0.00361
# Day 444 value: 5962.00 todayPL: $226.55 $-traded: 1592468 return: 0.00374
# Day 445 value: 5438.34 todayPL: $-523.66 $-traded: 1597053 return: 0.00341
# Day 446 value: 5392.88 todayPL: $-45.46 $-traded: 1602546 return: 0.00337
# Day 447 value: 5259.69 todayPL: $-133.19 $-traded: 1606948 return: 0.00327
# Day 448 value: 5440.16 todayPL: $180.47 $-traded: 1614582 return: 0.00337
# Day 449 value: 5374.06 todayPL: $-66.10 $-traded: 1620595 return: 0.00332
# Day 450 value: 5881.28 todayPL: $507.22 $-traded: 1627927 return: 0.00361
# Day 451 value: 5987.11 todayPL: $105.83 $-traded: 1633057 return: 0.00367
# Day 452 value: 6493.30 todayPL: $506.19 $-traded: 1642407 return: 0.00395
# Day 453 value: 6643.32 todayPL: $150.02 $-traded: 1645918 return: 0.00404
# Day 454 value: 6834.54 todayPL: $191.22 $-traded: 1650365 return: 0.00414
# Day 455 value: 7283.51 todayPL: $448.97 $-traded: 1656664 return: 0.00440
# Day 456 value: 7628.25 todayPL: $344.74 $-traded: 1664884 return: 0.00458
# Day 457 value: 7821.21 todayPL: $192.96 $-traded: 1670239 return: 0.00468
# Day 458 value: 8044.30 todayPL: $223.10 $-traded: 1676738 return: 0.00480
# Day 459 value: 7607.92 todayPL: $-436.38 $-traded: 1682998 return: 0.00452
# Day 460 value: 7864.86 todayPL: $256.94 $-traded: 1690794 return: 0.00465
# Day 461 value: 8064.06 todayPL: $199.20 $-traded: 1701526 return: 0.00474
# Day 462 value: 8645.85 todayPL: $581.79 $-traded: 1708691 return: 0.00506
# Day 463 value: 9105.83 todayPL: $459.98 $-traded: 1714978 return: 0.00531
# Day 464 value: 9330.12 todayPL: $224.29 $-traded: 1725034 return: 0.00541
# Day 465 value: 9306.07 todayPL: $-24.04 $-traded: 1732432 return: 0.00537
# Day 466 value: 9728.14 todayPL: $422.07 $-traded: 1741685 return: 0.00559
# Day 467 value: 9774.45 todayPL: $46.31 $-traded: 1749780 return: 0.00559
# Day 468 value: 9713.71 todayPL: $-60.74 $-traded: 1755696 return: 0.00553
# Day 469 value: 9759.62 todayPL: $45.91 $-traded: 1760944 return: 0.00554
# Day 470 value: 9949.54 todayPL: $189.92 $-traded: 1776371 return: 0.00560
# Day 471 value: 10227.83 todayPL: $278.29 $-traded: 1790332 return: 0.00571
# Day 472 value: 10361.70 todayPL: $133.87 $-traded: 1797638 return: 0.00576
# Day 473 value: 10455.45 todayPL: $93.75 $-traded: 1803670 return: 0.00580
# Day 474 value: 10053.43 todayPL: $-402.02 $-traded: 1808448 return: 0.00556
# Day 475 value: 9746.66 todayPL: $-306.77 $-traded: 1815042 return: 0.00537
# Day 476 value: 9409.98 todayPL: $-336.68 $-traded: 1822565 return: 0.00516
# Day 477 value: 9267.32 todayPL: $-142.66 $-traded: 1828112 return: 0.00507
# Day 478 value: 9340.54 todayPL: $73.22 $-traded: 1834198 return: 0.00509
# Day 479 value: 9028.24 todayPL: $-312.30 $-traded: 1842417 return: 0.00490
# Day 480 value: 8975.40 todayPL: $-52.84 $-traded: 1849707 return: 0.00485
# Day 481 value: 9223.38 todayPL: $247.98 $-traded: 1858125 return: 0.00496
# Day 482 value: 9111.89 todayPL: $-111.50 $-traded: 1865636 return: 0.00488
# Day 483 value: 9247.83 todayPL: $135.94 $-traded: 1872352 return: 0.00494
# Day 484 value: 9078.30 todayPL: $-169.54 $-traded: 1878059 return: 0.00483
# Day 485 value: 9192.49 todayPL: $114.19 $-traded: 1886529 return: 0.00487
# Day 486 value: 9268.06 todayPL: $75.57 $-traded: 1895667 return: 0.00489
# Day 487 value: 9432.92 todayPL: $164.86 $-traded: 1904629 return: 0.00495
# Day 488 value: 9583.17 todayPL: $150.25 $-traded: 1912972 return: 0.00501
# Day 489 value: 9628.57 todayPL: $45.40 $-traded: 1919297 return: 0.00502
# Day 490 value: 9996.50 todayPL: $367.93 $-traded: 1927105 return: 0.00519
# Day 491 value: 10120.86 todayPL: $124.35 $-traded: 1936434 return: 0.00523
# Day 492 value: 10502.30 todayPL: $381.44 $-traded: 1942464 return: 0.00541
# Day 493 value: 10433.61 todayPL: $-68.69 $-traded: 1946311 return: 0.00536
# Day 494 value: 10327.10 todayPL: $-106.51 $-traded: 1950195 return: 0.00530
# Day 495 value: 10333.40 todayPL: $6.30 $-traded: 1958519 return: 0.00528
# Day 496 value: 10239.28 todayPL: $-94.12 $-traded: 1964507 return: 0.00521
# Day 497 value: 10778.17 todayPL: $538.88 $-traded: 1970577 return: 0.00547
# Day 498 value: 10508.36 todayPL: $-269.81 $-traded: 1981380 return: 0.00530
# Day 499 value: 10241.56 todayPL: $-266.79 $-traded: 1988387 return: 0.00515
# Day 500 value: 10060.90 todayPL: $-180.67 $-traded: 1988509 return: 0.00506
# =====
# mean(PL): 40.1
# return: 0.00506
# StdDev(PL): 230.91
# annSharpe(PL): 2.74
# totDvolume: 1988509
# Score: 16.99

# %%
const = 249
audit_df = get_audit_table(signals, stop_loss_activated, suspension_activated, positions, todayPL_array, returns, commission_array, prcAll, final_model_dict, const)
audit_df.to_excel('audit_table_250_5day.xlsx')

# %%
START_DATE = 500

signals = np.zeros([50, 251])
positions = np.zeros([50, 251])
returns = np.zeros([50, 251])

values_array = np.zeros([50, 251])
cash_array = np.zeros([50, 251])
todayPL_array = np.zeros([50, 251])

commRate = 0.0010
dlrPosLimit = 10000

nInst = 50
currentPos = np.zeros(nInst)

def calcPL(prcHist):
    global pll
    cash = 0
    curPos = np.zeros(nInst)
    totDVolume = 0
    totDVolumeSignal = 0
    totDVolumeRandom = 0
    value = 0
    todayPLL = []
    (_, nt) = prcHist.shape
    for t in range(500, 751): # t will go from 250 to 500 (251 numbers)
        prcHistSoFar = prcHist[:, :t] # t=250 => will go from i.e. day 0 to day 249 (250 days). day = t-1; t = 500: don't trade - only lose brockerage
        newPosOrig = getMyPosition(prcHistSoFar) # day 250 train, then make positions for 251...
        curPrices = prcHistSoFar[:, -1]
        posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
        newPos = np.clip(newPosOrig, -posLimits, posLimits) # t0 make new positions
        deltaPos = newPos - curPos # t0 change position
        
        positions[:, prcHistSoFar.shape[1]-START_DATE] = newPos # record position
        
        dvolumes = curPrices * np.abs(deltaPos) # t0 transaction volumes
        dvolume = np.sum(dvolumes)
        totDVolume += dvolume 
        comm = dvolume * commRate # t0 commission
        cash -= curPrices.dot(deltaPos) + comm  # t0 change in cash: long/short stocks and commission

        cash_array[:, prcHistSoFar.shape[1]-START_DATE] = np.zeros([50]) - curPrices * deltaPos - np.abs(deltaPos) * curPrices * commRate if t == START_DATE \
              else cash_array[:, prcHistSoFar.shape[1]-START_DATE-1] - curPrices * deltaPos - np.abs(deltaPos) * curPrices * commRate

        curPos = np.array(newPos) 
        posValue = curPos.dot(curPrices) # value of stocks = what was earned from t-1's positions + value of t0 stocks. (balances out part of the cash change)
        todayPL = cash + posValue - value # today's profit/loss: cash + value of stocks - value of stocks at t-1 
        
        if t != START_DATE+250:
            returns[:, prcHistSoFar.shape[1]-START_DATE] = prcHist[:, t] / prcHist[:, t-1] - 1
            todayPL_array[:, prcHistSoFar.shape[1]-START_DATE] = cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices if t == START_DATE \
                else cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices - values_array[:, prcHistSoFar.shape[1]-START_DATE-1]

        todayPLL.append(todayPL) 
        value = cash + posValue

        values_array[:, prcHistSoFar.shape[1]-START_DATE] = cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices

        ret = 0.0
        if (totDVolume > 0):
            ret = value / totDVolume
        print("Day %d value: %.2lf todayPL: $%.2lf $-traded: %.0lf return: %.5lf" %
              (t, value, todayPL, totDVolume, ret))
    pll = np.array(todayPLL)
    (plmu, plstd) = (np.mean(pll), np.std(pll))
    annSharpe = 0.0
    if (plstd > 0):
        annSharpe = np.sqrt(250) * plmu / plstd
    return (plmu, ret, plstd, annSharpe, totDVolume)


(meanpl, ret, plstd, sharpe, dvol) = calcPL(prcAll)
score = meanpl - 0.1*plstd
print("=====")
print("mean(PL): %.1lf" % meanpl)
print("return: %.5lf" % ret)
print("StdDev(PL): %.2lf" % plstd)
print("annSharpe(PL): %.2lf " % sharpe)
print("totDvolume: %.0lf " % dvol)
print("Score: %.2lf" % score)
# Out:
# Day 500 value: -15.00 todayPL: $-15.00 $-traded: 15000 return: -0.00100
# Day 501 value: -71.63 todayPL: $-56.63 $-traded: 61933 return: -0.00116
# Day 502 value: -92.23 todayPL: $-20.60 $-traded: 103369 return: -0.00089
# Day 503 value: 22.53 todayPL: $114.76 $-traded: 135906 return: 0.00017
# Day 504 value: -162.33 todayPL: $-184.87 $-traded: 164482 return: -0.00099
# Day 505 value: -109.51 todayPL: $52.83 $-traded: 189737 return: -0.00058
# Day 506 value: -141.41 todayPL: $-31.91 $-traded: 220463 return: -0.00064
# Day 507 value: -68.43 todayPL: $72.98 $-traded: 246612 return: -0.00028
# Day 508 value: -113.96 todayPL: $-45.53 $-traded: 272894 return: -0.00042
# Day 509 value: -511.88 todayPL: $-397.91 $-traded: 298294 return: -0.00172
# Day 510 value: -451.99 todayPL: $59.88 $-traded: 310381 return: -0.00146
# Day 511 value: -633.33 todayPL: $-181.33 $-traded: 319110 return: -0.00198
# Day 512 value: -952.96 todayPL: $-319.63 $-traded: 326942 return: -0.00291
# Day 513 value: -763.51 todayPL: $189.45 $-traded: 332870 return: -0.00229
# Day 514 value: -683.60 todayPL: $79.92 $-traded: 341488 return: -0.00200
# Day 515 value: -846.69 todayPL: $-163.09 $-traded: 348114 return: -0.00243
# Day 516 value: -550.88 todayPL: $295.80 $-traded: 354233 return: -0.00156
# Day 517 value: -546.52 todayPL: $4.36 $-traded: 361423 return: -0.00151
# Day 518 value: -510.44 todayPL: $36.09 $-traded: 371313 return: -0.00137
# Day 519 value: -388.65 todayPL: $121.78 $-traded: 380170 return: -0.00102
# Day 520 value: -59.81 todayPL: $328.84 $-traded: 386526 return: -0.00015
# Day 521 value: 30.37 todayPL: $90.19 $-traded: 391811 return: 0.00008
# Day 522 value: 355.72 todayPL: $325.35 $-traded: 398735 return: 0.00089
# Day 523 value: 483.21 todayPL: $127.49 $-traded: 404635 return: 0.00119
# Day 524 value: 571.09 todayPL: $87.88 $-traded: 407783 return: 0.00140
# Day 525 value: 922.96 todayPL: $351.86 $-traded: 411057 return: 0.00225
# Day 526 value: 1139.49 todayPL: $216.53 $-traded: 412426 return: 0.00276
# Day 527 value: 1276.17 todayPL: $136.68 $-traded: 418361 return: 0.00305
# Day 528 value: 1173.37 todayPL: $-102.79 $-traded: 427681 return: 0.00274
# Day 529 value: 1563.88 todayPL: $390.51 $-traded: 436158 return: 0.00359
# Day 530 value: 1513.53 todayPL: $-50.35 $-traded: 444870 return: 0.00340
# Day 531 value: 1495.77 todayPL: $-17.75 $-traded: 452940 return: 0.00330
# Day 532 value: 1560.85 todayPL: $65.08 $-traded: 462190 return: 0.00338
# Day 533 value: 1567.31 todayPL: $6.47 $-traded: 470940 return: 0.00333
# Day 534 value: 1518.69 todayPL: $-48.62 $-traded: 481172 return: 0.00316
# Day 535 value: 1509.89 todayPL: $-8.80 $-traded: 489805 return: 0.00308
# Day 536 value: 1717.42 todayPL: $207.53 $-traded: 500706 return: 0.00343
# Day 537 value: 1545.27 todayPL: $-172.15 $-traded: 511006 return: 0.00302
# Day 538 value: 1479.13 todayPL: $-66.13 $-traded: 522929 return: 0.00283
# Day 539 value: 1455.11 todayPL: $-24.02 $-traded: 535341 return: 0.00272
# Day 540 value: 1349.52 todayPL: $-105.60 $-traded: 548671 return: 0.00246
# Day 541 value: 1030.25 todayPL: $-319.26 $-traded: 560617 return: 0.00184
# Day 542 value: 983.28 todayPL: $-46.98 $-traded: 569781 return: 0.00173
# Day 543 value: 1130.11 todayPL: $146.83 $-traded: 575853 return: 0.00196
# Day 544 value: 1165.37 todayPL: $35.26 $-traded: 584060 return: 0.00200
# Day 545 value: 1270.92 todayPL: $105.54 $-traded: 591407 return: 0.00215
# Day 546 value: 1438.27 todayPL: $167.35 $-traded: 598603 return: 0.00240
# Day 547 value: 1693.82 todayPL: $255.55 $-traded: 605799 return: 0.00280
# Day 548 value: 1820.34 todayPL: $126.52 $-traded: 613179 return: 0.00297
# Day 549 value: 1601.18 todayPL: $-219.16 $-traded: 617395 return: 0.00259
# Day 550 value: 1415.68 todayPL: $-185.50 $-traded: 621127 return: 0.00228
# Day 551 value: 1437.95 todayPL: $22.27 $-traded: 624957 return: 0.00230
# Day 552 value: 1135.42 todayPL: $-302.53 $-traded: 632037 return: 0.00180
# Day 553 value: 1119.47 todayPL: $-15.96 $-traded: 637248 return: 0.00176
# Day 554 value: 1218.14 todayPL: $98.68 $-traded: 643351 return: 0.00189
# Day 555 value: 1331.72 todayPL: $113.58 $-traded: 648077 return: 0.00205
# Day 556 value: 1266.50 todayPL: $-65.22 $-traded: 653352 return: 0.00194
# Day 557 value: 1329.61 todayPL: $63.11 $-traded: 660498 return: 0.00201
# Day 558 value: 1403.68 todayPL: $74.07 $-traded: 663711 return: 0.00211
# Day 559 value: 1554.45 todayPL: $150.77 $-traded: 667776 return: 0.00233
# Day 560 value: 1499.81 todayPL: $-54.64 $-traded: 673223 return: 0.00223
# Day 561 value: 1860.20 todayPL: $360.38 $-traded: 678037 return: 0.00274
# Day 562 value: 1855.04 todayPL: $-5.15 $-traded: 681877 return: 0.00272
# Day 563 value: 1403.79 todayPL: $-451.25 $-traded: 689949 return: 0.00203
# Day 564 value: 1519.23 todayPL: $115.44 $-traded: 697955 return: 0.00218
# Day 565 value: 1562.34 todayPL: $43.11 $-traded: 706453 return: 0.00221
# Day 566 value: 1709.40 todayPL: $147.05 $-traded: 715515 return: 0.00239
# Day 567 value: 1815.64 todayPL: $106.25 $-traded: 724731 return: 0.00251
# Day 568 value: 1874.99 todayPL: $59.34 $-traded: 731538 return: 0.00256
# Day 569 value: 1846.28 todayPL: $-28.71 $-traded: 738808 return: 0.00250
# Day 570 value: 1684.75 todayPL: $-161.53 $-traded: 746362 return: 0.00226
# Day 571 value: 1601.73 todayPL: $-83.03 $-traded: 753685 return: 0.00213
# Day 572 value: 1355.36 todayPL: $-246.37 $-traded: 762565 return: 0.00178
# Day 573 value: 1886.94 todayPL: $531.59 $-traded: 768304 return: 0.00246
# Day 574 value: 1683.30 todayPL: $-203.64 $-traded: 774828 return: 0.00217
# Day 575 value: 1498.73 todayPL: $-184.57 $-traded: 782798 return: 0.00191
# Day 576 value: 1417.55 todayPL: $-81.18 $-traded: 788710 return: 0.00180
# Day 577 value: 1778.61 todayPL: $361.05 $-traded: 792736 return: 0.00224
# Day 578 value: 1830.39 todayPL: $51.79 $-traded: 798504 return: 0.00229
# Day 579 value: 1699.13 todayPL: $-131.26 $-traded: 806593 return: 0.00211
# Day 580 value: 2142.55 todayPL: $443.42 $-traded: 814421 return: 0.00263
# Day 581 value: 2201.28 todayPL: $58.72 $-traded: 822127 return: 0.00268
# Day 582 value: 2540.59 todayPL: $339.31 $-traded: 829095 return: 0.00306
# Day 583 value: 2345.92 todayPL: $-194.67 $-traded: 837788 return: 0.00280
# Day 584 value: 2684.67 todayPL: $338.76 $-traded: 846872 return: 0.00317
# Day 585 value: 2662.62 todayPL: $-22.05 $-traded: 855237 return: 0.00311
# Day 586 value: 2697.69 todayPL: $35.07 $-traded: 863743 return: 0.00312
# Day 587 value: 2614.83 todayPL: $-82.86 $-traded: 874054 return: 0.00299
# Day 588 value: 2386.09 todayPL: $-228.73 $-traded: 880187 return: 0.00271
# Day 589 value: 2254.81 todayPL: $-131.29 $-traded: 886801 return: 0.00254
# Day 590 value: 2268.82 todayPL: $14.02 $-traded: 892289 return: 0.00254
# Day 591 value: 2405.59 todayPL: $136.77 $-traded: 897152 return: 0.00268
# Day 592 value: 2038.15 todayPL: $-367.44 $-traded: 900964 return: 0.00226
# Day 593 value: 2241.95 todayPL: $203.80 $-traded: 903453 return: 0.00248
# Day 594 value: 2134.66 todayPL: $-107.29 $-traded: 906685 return: 0.00235
# Day 595 value: 2074.14 todayPL: $-60.52 $-traded: 910744 return: 0.00228
# Day 596 value: 2352.90 todayPL: $278.76 $-traded: 914419 return: 0.00257
# Day 597 value: 2134.86 todayPL: $-218.04 $-traded: 918800 return: 0.00232
# Day 598 value: 2098.83 todayPL: $-36.03 $-traded: 924239 return: 0.00227
# Day 599 value: 2204.54 todayPL: $105.72 $-traded: 932713 return: 0.00236
# Day 600 value: 2178.09 todayPL: $-26.46 $-traded: 938721 return: 0.00232
# Day 601 value: 2106.67 todayPL: $-71.42 $-traded: 941983 return: 0.00224
# Day 602 value: 2347.17 todayPL: $240.50 $-traded: 949374 return: 0.00247
# Day 603 value: 2612.06 todayPL: $264.89 $-traded: 955788 return: 0.00273
# Day 604 value: 2511.06 todayPL: $-101.00 $-traded: 959850 return: 0.00262
# Day 605 value: 2601.39 todayPL: $90.33 $-traded: 964054 return: 0.00270
# Day 606 value: 2424.03 todayPL: $-177.36 $-traded: 967526 return: 0.00251
# Day 607 value: 2260.43 todayPL: $-163.60 $-traded: 973689 return: 0.00232
# Day 608 value: 2430.35 todayPL: $169.92 $-traded: 977167 return: 0.00249
# Day 609 value: 2481.60 todayPL: $51.25 $-traded: 985474 return: 0.00252
# Day 610 value: 2497.71 todayPL: $16.11 $-traded: 991498 return: 0.00252
# Day 611 value: 2348.98 todayPL: $-148.73 $-traded: 999609 return: 0.00235
# Day 612 value: 2551.15 todayPL: $202.17 $-traded: 1006095 return: 0.00254
# Day 613 value: 2810.32 todayPL: $259.17 $-traded: 1012790 return: 0.00277
# Day 614 value: 2889.84 todayPL: $79.52 $-traded: 1017505 return: 0.00284
# Day 615 value: 3043.14 todayPL: $153.29 $-traded: 1022265 return: 0.00298
# Day 616 value: 2769.72 todayPL: $-273.42 $-traded: 1024859 return: 0.00270
# Day 617 value: 3151.59 todayPL: $381.88 $-traded: 1028935 return: 0.00306
# Day 618 value: 3655.64 todayPL: $504.05 $-traded: 1033774 return: 0.00354
# Day 619 value: 3503.05 todayPL: $-152.59 $-traded: 1041154 return: 0.00336
# Day 620 value: 3367.34 todayPL: $-135.71 $-traded: 1047120 return: 0.00322
# Day 621 value: 3635.10 todayPL: $267.76 $-traded: 1055288 return: 0.00344
# Day 622 value: 3572.43 todayPL: $-62.67 $-traded: 1061756 return: 0.00336
# Day 623 value: 3627.11 todayPL: $54.68 $-traded: 1067182 return: 0.00340
# Day 624 value: 3643.02 todayPL: $15.90 $-traded: 1073803 return: 0.00339
# Day 625 value: 3825.99 todayPL: $182.98 $-traded: 1081803 return: 0.00354
# Day 626 value: 3811.52 todayPL: $-14.48 $-traded: 1089883 return: 0.00350
# Day 627 value: 3637.47 todayPL: $-174.05 $-traded: 1098015 return: 0.00331
# Day 628 value: 3518.44 todayPL: $-119.03 $-traded: 1105494 return: 0.00318
# Day 629 value: 3213.84 todayPL: $-304.60 $-traded: 1109588 return: 0.00290
# Day 630 value: 3639.62 todayPL: $425.77 $-traded: 1113221 return: 0.00327
# Day 631 value: 3746.48 todayPL: $106.86 $-traded: 1119268 return: 0.00335
# Day 632 value: 3563.65 todayPL: $-182.83 $-traded: 1125448 return: 0.00317
# Day 633 value: 3934.78 todayPL: $371.13 $-traded: 1132744 return: 0.00347
# Day 634 value: 4195.15 todayPL: $260.37 $-traded: 1137634 return: 0.00369
# Day 635 value: 4066.70 todayPL: $-128.45 $-traded: 1143995 return: 0.00355
# Day 636 value: 3854.70 todayPL: $-211.99 $-traded: 1151698 return: 0.00335
# Day 637 value: 3786.81 todayPL: $-67.89 $-traded: 1160042 return: 0.00326
# Day 638 value: 3958.54 todayPL: $171.73 $-traded: 1164719 return: 0.00340
# Day 639 value: 3768.14 todayPL: $-190.40 $-traded: 1168130 return: 0.00323
# Day 640 value: 3947.44 todayPL: $179.30 $-traded: 1171015 return: 0.00337
# Day 641 value: 3652.59 todayPL: $-294.84 $-traded: 1175345 return: 0.00311
# Day 642 value: 3466.75 todayPL: $-185.85 $-traded: 1181645 return: 0.00293
# Day 643 value: 3302.43 todayPL: $-164.32 $-traded: 1185350 return: 0.00279
# Day 644 value: 3255.16 todayPL: $-47.27 $-traded: 1187867 return: 0.00274
# Day 645 value: 2943.25 todayPL: $-311.91 $-traded: 1190911 return: 0.00247
# Day 646 value: 2705.24 todayPL: $-238.00 $-traded: 1196234 return: 0.00226
# Day 647 value: 2923.90 todayPL: $218.66 $-traded: 1199232 return: 0.00244
# Day 648 value: 2891.05 todayPL: $-32.85 $-traded: 1205210 return: 0.00240
# Day 649 value: 2946.58 todayPL: $55.52 $-traded: 1208371 return: 0.00244
# Day 650 value: 2685.05 todayPL: $-261.53 $-traded: 1213943 return: 0.00221
# Day 651 value: 2607.03 todayPL: $-78.03 $-traded: 1220486 return: 0.00214
# Day 652 value: 2058.62 todayPL: $-548.41 $-traded: 1226251 return: 0.00168
# Day 653 value: 2081.08 todayPL: $22.47 $-traded: 1231520 return: 0.00169
# Day 654 value: 2016.36 todayPL: $-64.72 $-traded: 1235479 return: 0.00163
# Day 655 value: 1881.49 todayPL: $-134.87 $-traded: 1239384 return: 0.00152
# Day 656 value: 2037.12 todayPL: $155.64 $-traded: 1245755 return: 0.00164
# Day 657 value: 2181.28 todayPL: $144.16 $-traded: 1253002 return: 0.00174
# Day 658 value: 1929.15 todayPL: $-252.13 $-traded: 1263228 return: 0.00153
# Day 659 value: 1885.32 todayPL: $-43.82 $-traded: 1273078 return: 0.00148
# Day 660 value: 2045.83 todayPL: $160.51 $-traded: 1286335 return: 0.00159
# Day 661 value: 1875.05 todayPL: $-170.78 $-traded: 1296864 return: 0.00145
# Day 662 value: 2065.61 todayPL: $190.56 $-traded: 1308216 return: 0.00158
# Day 663 value: 2034.80 todayPL: $-30.81 $-traded: 1312745 return: 0.00155
# Day 664 value: 1939.04 todayPL: $-95.76 $-traded: 1319456 return: 0.00147
# Day 665 value: 2252.55 todayPL: $313.50 $-traded: 1328424 return: 0.00170
# Day 666 value: 2731.44 todayPL: $478.89 $-traded: 1334741 return: 0.00205
# Day 667 value: 2911.36 todayPL: $179.92 $-traded: 1341101 return: 0.00217
# Day 668 value: 2924.20 todayPL: $12.84 $-traded: 1345121 return: 0.00217
# Day 669 value: 3109.64 todayPL: $185.44 $-traded: 1353200 return: 0.00230
# Day 670 value: 3193.56 todayPL: $83.93 $-traded: 1360355 return: 0.00235
# Day 671 value: 3168.14 todayPL: $-25.43 $-traded: 1369353 return: 0.00231
# Day 672 value: 3247.12 todayPL: $78.98 $-traded: 1376424 return: 0.00236
# Day 673 value: 2980.18 todayPL: $-266.94 $-traded: 1384412 return: 0.00215
# Day 674 value: 2993.02 todayPL: $12.83 $-traded: 1391881 return: 0.00215
# Day 675 value: 3079.85 todayPL: $86.84 $-traded: 1397624 return: 0.00220
# Day 676 value: 3158.84 todayPL: $78.99 $-traded: 1401801 return: 0.00225
# Day 677 value: 3336.00 todayPL: $177.16 $-traded: 1406733 return: 0.00237
# Day 678 value: 3539.63 todayPL: $203.63 $-traded: 1412755 return: 0.00251
# Day 679 value: 3563.44 todayPL: $23.81 $-traded: 1417386 return: 0.00251
# Day 680 value: 3568.70 todayPL: $5.26 $-traded: 1422859 return: 0.00251
# Day 681 value: 3289.10 todayPL: $-279.60 $-traded: 1429949 return: 0.00230
# Day 682 value: 3766.39 todayPL: $477.29 $-traded: 1435124 return: 0.00262
# Day 683 value: 3855.61 todayPL: $89.22 $-traded: 1440618 return: 0.00268
# Day 684 value: 3868.45 todayPL: $12.84 $-traded: 1445236 return: 0.00268
# Day 685 value: 3837.92 todayPL: $-30.54 $-traded: 1450492 return: 0.00265
# Day 686 value: 4036.89 todayPL: $198.97 $-traded: 1457622 return: 0.00277
# Day 687 value: 4173.73 todayPL: $136.84 $-traded: 1468227 return: 0.00284
# Day 688 value: 3978.96 todayPL: $-194.76 $-traded: 1484505 return: 0.00268
# Day 689 value: 3648.65 todayPL: $-330.31 $-traded: 1499844 return: 0.00243
# Day 690 value: 3585.69 todayPL: $-62.96 $-traded: 1516314 return: 0.00236
# Day 691 value: 4311.32 todayPL: $725.63 $-traded: 1529303 return: 0.00282
# Day 692 value: 4430.45 todayPL: $119.13 $-traded: 1539969 return: 0.00288
# Day 693 value: 4767.17 todayPL: $336.72 $-traded: 1551637 return: 0.00307
# Day 694 value: 4682.70 todayPL: $-84.47 $-traded: 1563757 return: 0.00299
# Day 695 value: 4578.60 todayPL: $-104.10 $-traded: 1570269 return: 0.00292
# Day 696 value: 4536.39 todayPL: $-42.21 $-traded: 1575303 return: 0.00288
# Day 697 value: 4568.16 todayPL: $31.77 $-traded: 1580196 return: 0.00289
# Day 698 value: 4578.49 todayPL: $10.33 $-traded: 1584872 return: 0.00289
# Day 699 value: 4365.89 todayPL: $-212.60 $-traded: 1593114 return: 0.00274
# Day 700 value: 3859.15 todayPL: $-506.75 $-traded: 1599732 return: 0.00241
# Day 701 value: 3717.67 todayPL: $-141.47 $-traded: 1607763 return: 0.00231
# Day 702 value: 3949.78 todayPL: $232.11 $-traded: 1616164 return: 0.00244
# Day 703 value: 3944.08 todayPL: $-5.70 $-traded: 1621692 return: 0.00243
# Day 704 value: 3899.26 todayPL: $-44.82 $-traded: 1627893 return: 0.00240
# Day 705 value: 3980.88 todayPL: $81.62 $-traded: 1636742 return: 0.00243
# Day 706 value: 3929.24 todayPL: $-51.64 $-traded: 1643861 return: 0.00239
# Day 707 value: 3895.85 todayPL: $-33.39 $-traded: 1652616 return: 0.00236
# Day 708 value: 3570.18 todayPL: $-325.67 $-traded: 1664322 return: 0.00215
# Day 709 value: 3238.62 todayPL: $-331.57 $-traded: 1674057 return: 0.00193
# Day 710 value: 3317.28 todayPL: $78.67 $-traded: 1681164 return: 0.00197
# Day 711 value: 3077.30 todayPL: $-239.98 $-traded: 1688337 return: 0.00182
# Day 712 value: 3140.83 todayPL: $63.53 $-traded: 1692846 return: 0.00186
# Day 713 value: 3145.04 todayPL: $4.20 $-traded: 1699533 return: 0.00185
# Day 714 value: 3200.52 todayPL: $55.48 $-traded: 1709468 return: 0.00187
# Day 715 value: 3182.79 todayPL: $-17.73 $-traded: 1715210 return: 0.00186
# Day 716 value: 2780.21 todayPL: $-402.58 $-traded: 1721184 return: 0.00162
# Day 717 value: 3029.72 todayPL: $249.51 $-traded: 1727496 return: 0.00175
# Day 718 value: 2849.09 todayPL: $-180.64 $-traded: 1735230 return: 0.00164
# Day 719 value: 2566.40 todayPL: $-282.69 $-traded: 1743383 return: 0.00147
# Day 720 value: 2448.79 todayPL: $-117.61 $-traded: 1752929 return: 0.00140
# Day 721 value: 2464.30 todayPL: $15.51 $-traded: 1760664 return: 0.00140
# Day 722 value: 2092.24 todayPL: $-372.06 $-traded: 1766516 return: 0.00118
# Day 723 value: 2234.27 todayPL: $142.03 $-traded: 1771939 return: 0.00126
# Day 724 value: 2028.90 todayPL: $-205.37 $-traded: 1778080 return: 0.00114
# Day 725 value: 1587.08 todayPL: $-441.82 $-traded: 1783192 return: 0.00089
# Day 726 value: 1879.23 todayPL: $292.15 $-traded: 1788283 return: 0.00105
# Day 727 value: 2104.70 todayPL: $225.47 $-traded: 1794477 return: 0.00117
# Day 728 value: 1779.31 todayPL: $-325.38 $-traded: 1802122 return: 0.00099
# Day 729 value: 1991.83 todayPL: $212.51 $-traded: 1808102 return: 0.00110
# Day 730 value: 2242.94 todayPL: $251.11 $-traded: 1816213 return: 0.00123
# Day 731 value: 2669.20 todayPL: $426.26 $-traded: 1825268 return: 0.00146
# Day 732 value: 2443.56 todayPL: $-225.64 $-traded: 1835418 return: 0.00133
# Day 733 value: 2490.77 todayPL: $47.21 $-traded: 1848839 return: 0.00135
# Day 734 value: 2685.23 todayPL: $194.46 $-traded: 1857050 return: 0.00145
# Day 735 value: 2904.62 todayPL: $219.39 $-traded: 1863068 return: 0.00156
# Day 736 value: 3113.69 todayPL: $209.06 $-traded: 1868363 return: 0.00167
# Day 737 value: 3263.15 todayPL: $149.46 $-traded: 1874665 return: 0.00174
# Day 738 value: 3328.38 todayPL: $65.23 $-traded: 1882481 return: 0.00177
# Day 739 value: 3364.25 todayPL: $35.87 $-traded: 1889189 return: 0.00178
# Day 740 value: 3514.40 todayPL: $150.15 $-traded: 1893878 return: 0.00186
# Day 741 value: 3690.42 todayPL: $176.03 $-traded: 1897415 return: 0.00194
# Day 742 value: 3610.98 todayPL: $-79.44 $-traded: 1900612 return: 0.00190
# Day 743 value: 3743.26 todayPL: $132.27 $-traded: 1903435 return: 0.00197
# Day 744 value: 4094.24 todayPL: $350.98 $-traded: 1907070 return: 0.00215
# Day 745 value: 4278.34 todayPL: $184.10 $-traded: 1910613 return: 0.00224
# Day 746 value: 4519.62 todayPL: $241.27 $-traded: 1913652 return: 0.00236
# Day 747 value: 4477.57 todayPL: $-42.04 $-traded: 1917715 return: 0.00233
# Day 748 value: 4800.20 todayPL: $322.63 $-traded: 1922944 return: 0.00250
# Day 749 value: 4929.71 todayPL: $129.51 $-traded: 1930254 return: 0.00255
# Day 750 value: 4844.60 todayPL: $-85.11 $-traded: 1930305 return: 0.00251
# =====
# mean(PL): 19.3
# return: 0.00251
# StdDev(PL): 205.44
# annSharpe(PL): 1.49
# totDvolume: 1930305
# Score: -1.24

# %%
const = 249+250
audit_df = get_audit_table(signals, stop_loss_activated, suspension_activated, positions, todayPL_array, returns, commission_array, prcAll, final_model_dict, const)
audit_df.to_excel('audit_table_500_5_days.xlsx')

# %%
START_DATE = 750

signals = np.zeros([50, 251])
positions = np.zeros([50, 251])
returns = np.zeros([50, 251])

values_array = np.zeros([50, 251])
cash_array = np.zeros([50, 251])
todayPL_array = np.zeros([50, 251])

commRate = 0.0010
dlrPosLimit = 10000

nInst = 50
currentPos = np.zeros(nInst)

def calcPL(prcHist):
    global pll
    cash = 0
    curPos = np.zeros(nInst)
    totDVolume = 0
    totDVolumeSignal = 0
    totDVolumeRandom = 0
    value = 0
    todayPLL = []
    (_, nt) = prcHist.shape
    for t in range(750, 1001): # t will go from 250 to 500 (251 numbers)
        prcHistSoFar = prcHist[:, :t] # t=250 => will go from i.e. day 0 to day 249 (250 days). day = t-1; t = 500: don't trade - only lose brockerage
        newPosOrig = getMyPosition(prcHistSoFar) # day 250 train, then make positions for 251...
        curPrices = prcHistSoFar[:, -1]
        posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
        newPos = np.clip(newPosOrig, -posLimits, posLimits) # t0 make new positions
        deltaPos = newPos - curPos # t0 change position
        
        positions[:, prcHistSoFar.shape[1]-START_DATE] = newPos # record position
        
        dvolumes = curPrices * np.abs(deltaPos) # t0 transaction volumes
        dvolume = np.sum(dvolumes)
        totDVolume += dvolume 
        comm = dvolume * commRate # t0 commission
        cash -= curPrices.dot(deltaPos) + comm  # t0 change in cash: long/short stocks and commission

        cash_array[:, prcHistSoFar.shape[1]-START_DATE] = np.zeros([50]) - curPrices * deltaPos - np.abs(deltaPos) * curPrices * commRate if t == START_DATE \
              else cash_array[:, prcHistSoFar.shape[1]-START_DATE-1] - curPrices * deltaPos - np.abs(deltaPos) * curPrices * commRate

        curPos = np.array(newPos) 
        posValue = curPos.dot(curPrices) # value of stocks = what was earned from t-1's positions + value of t0 stocks. (balances out part of the cash change)
        todayPL = cash + posValue - value # today's profit/loss: cash + value of stocks - value of stocks at t-1 
        
        if t != START_DATE+250:
            returns[:, prcHistSoFar.shape[1]-START_DATE] = prcHist[:, t] / prcHist[:, t-1] - 1
            todayPL_array[:, prcHistSoFar.shape[1]-START_DATE] = cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices if t == START_DATE \
                else cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices - values_array[:, prcHistSoFar.shape[1]-START_DATE-1]

        todayPLL.append(todayPL) 
        value = cash + posValue

        values_array[:, prcHistSoFar.shape[1]-START_DATE] = cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices

        ret = 0.0
        if (totDVolume > 0):
            ret = value / totDVolume
        print("Day %d value: %.2lf todayPL: $%.2lf $-traded: %.0lf return: %.5lf" %
              (t, value, todayPL, totDVolume, ret))
    pll = np.array(todayPLL)
    (plmu, plstd) = (np.mean(pll), np.std(pll))
    annSharpe = 0.0
    if (plstd > 0):
        annSharpe = np.sqrt(250) * plmu / plstd
    return (plmu, ret, plstd, annSharpe, totDVolume)


(meanpl, ret, plstd, sharpe, dvol) = calcPL(prcAll)
score = meanpl - 0.1*plstd
print("=====")
print("mean(PL): %.1lf" % meanpl)
print("return: %.5lf" % ret)
print("StdDev(PL): %.2lf" % plstd)
print("annSharpe(PL): %.2lf " % sharpe)
print("totDvolume: %.0lf " % dvol)
print("Score: %.2lf" % score)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_84504/2761959842.py in <module>
#      71
#      72
# ---> 73 (meanpl, ret, plstd, sharpe, dvol) = calcPL(prcAll)
#      74 score = meanpl - 0.1*plstd
#      75 print("=====")
#
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_84504/2761959842.py in calcPL(prcHist)
#      49
#      50         if t != START_DATE+250:
# ---> 51             returns[:, prcHistSoFar.shape[1]-START_DATE] = prcHist[:, t] / prcHist[:, t-1] - 1
#      52             todayPL_array[:, prcHistSoFar.shape[1]-START_DATE] = cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices if t == START_DATE \
#      53                 else cash_array[:, prcHistSoFar.shape[1]-START_DATE] + curPos * curPrices - values_array[:, prcHistSoFar.shape[1]-START_DATE-1]
#
# IndexError: index 750 is out of bounds for axis 1 with size 750

# %%
const = 249+500
audit_df = get_audit_table(signals, stop_loss_activated, suspension_activated, positions, todayPL_array, returns, commission_array, prcAll, final_model_dict, const)
audit_df.to_excel('audit_table_750.xlsx')

# %% [markdown]
# # Evaluation

# %%
# returns_flatten = returns[:250].flatten()
# signals_flatten = signals[:250].flatten()

# buckets = {}
# for i in range(-51, 51, 5):
#     buckets[(i, i+1)] = [returns_flatten[j] for j in range(len(returns_flatten)) if signals_flatten[j] >= i and signals_flatten[j] < i+1]
# buckets = [(key, np.mean(value)) for key, value in buckets.items()]

# # Extract the mid-point of each bucket range and the mean returns
# bucket_midpoints = [(key[0] + key[1]) / 2 for key, value in buckets]
# bucket_means = [value for key, value in buckets]

# # Plotting
# plt.figure(figsize=(12, 6))
# plt.scatter(bucket_midpoints, bucket_means, color='blue')
# plt.xlabel('Signal Buckets Midpoints')
# plt.ylabel('Mean Returns')
# plt.axvline(x=0, color='r', linestyle='-')
# plt.axhline(y=0, color='r', linestyle='-')
# plt.title('Mean Returns per Signal Bucket')
# plt.grid(True)
# plt.show()

# %%
# plt.plot(np.cumsum(pll))
# plt.axhline(y=0, color='r', linestyle='-')

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Assuming todayPL_array and positions are already defined and have appropriate shapes.

# for i in range(50):
#     plt.figure(figsize=(10, 6))  # Adjust the figure size if necessary
    
#     # Plot the cumulative PnL
#     plt.plot(100*(prcAll[i, 250:] - np.mean(prcAll[i, 250:]))/np.std(prcAll[i, 250:]), label='Price')
    
#     # Add the bar chart at y = 0
#     plt.bar(range(250), positions[i, :250], alpha=0.3, label='Positions', color='orange')
    
#     # Adding a title and labels
#     plt.title(f'Stock {i} Cost-included Cumulative PnL')
#     plt.xlabel('Time')
#     plt.ylabel('Cumulative PnL')
    
#     # Adding a legend
#     plt.legend()
    
#     # Show the plot
#     plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Assuming todayPL_array and positions are already defined and have appropriate shapes.

# for i in range(50):
#     plt.figure(figsize=(10, 6))  # Adjust the figure size if necessary
    
#     # Plot the cumulative PnL
#     plt.plot(np.cumsum(todayPL_array[i, :250]), label='Cumulative PnL')
    
#     # Add the bar chart at y = 0
#     plt.bar(range(250), positions[i, :250], alpha=0.3, label='Positions', color='orange')
    
#     # Adding a title and labels
#     plt.title(f'Stock {i} Cost-included Cumulative PnL')
#     plt.xlabel('Time')
#     plt.ylabel('Cumulative PnL')
    
#     # Adding a legend
#     plt.legend()
    
#     # Show the plot
#     plt.show()

# %% [markdown]
# # Graveyard

# %% [markdown]
# #### Univariate

# %%
# todo: class this

def build_univariate_linear_regression(log_return_df, target_stock, feature_stock, features, test_start_date, train_length):

    data = log_return_df[[f'{target_column}{target_stock}']+[f'{_}_{feature_stock}' for _ in features]].iloc[test_start_date-train_length:test_start_date]
    data.dropna(inplace=True)

    y = data[f'{target_column}{target_stock}']
    X = data.drop(columns=[f'{target_column}{target_stock}'])
    X = X.assign(const=1)
        
    # build models
    model = OLS(y, X).fit()

    return model

def inference_univariate_linear_regression(log_return_df, model, target_stock, feature_stock, features, test_start_date, train_length):
    
    X = log_return_df[[f'{_}_{feature_stock}' for _ in features]].iloc[-1:]

    X = X.assign(const=1)
    
    pred_t1 = model.predict(X).values[0]

    return pred_t1

def predict_train_univariate(log_return_df, model, target_stock, feature_stock, features, test_start_date, train_length):
    
    data = log_return_df[[f'{target_column}{target_stock}']+[f'{_}_{feature_stock}' for _ in features]].iloc[test_start_date-train_length:test_start_date]
    data.dropna(inplace=True)

    y = data[f'{target_column}{target_stock}']
    
    X = data.drop(columns=[f'{target_column}{target_stock}'])
    X = X.assign(const=1)

    y_pred = model.predict(X)
    
    return y, y_pred

# %% [markdown]
# ##### Difference

# %%
def build_difference_linear_regression(log_return_df, target_stock, features, test_start_date, train_length):

    data = log_return_df[[f'{target_column}{target_stock[0]}_{target_stock[1]}']+[f'{_}_{target_stock[0]}' for _ in features]+[f'{_}_{target_stock[1]}' for _ in features]].iloc[test_start_date-train_length:test_start_date]
    data.dropna(inplace=True)

    y = data[f'{target_column}{target_stock[0]}_{target_stock[1]}']
    X = data.drop(columns=[f'{target_column}{target_stock[0]}_{target_stock[1]}'])
    X = X.assign(const=1)

    # build models
    model = OLS(y, X).fit()

    return model

def inference_difference_linear_regression(log_return_df, model, target_stock, features, test_start_date, train_length):
    
    X = log_return_df[[f'{_}_{target_stock[0]}' for _ in features]+[f'{_}_{target_stock[1]}' for _ in features]].iloc[-1:]

    X = X.assign(const=1)
    
    pred_t1 = model.predict(X).values[0]

    return pred_t1

def predict_train_difference(log_return_df, model, target_stock, features, test_start_date, train_length):
    
    data = log_return_df[[f'{target_column}{target_stock[0]}_{target_stock[1]}']+[f'{_}_{target_stock[0]}' for _ in features]+[f'{_}_{target_stock[1]}' for _ in features]].iloc[test_start_date-train_length:test_start_date]
    data.dropna(inplace=True)

    y = data[f'{target_column}{target_stock[0]}_{target_stock[1]}']
    X = data.drop(columns=[f'{target_column}{target_stock[0]}_{target_stock[1]}'])
    X = X.assign(const=1)

    y_pred = model.predict(X)
    
    return y, y_pred

# %%
good_model_dict = defaultdict(dict)
model_accuracy_dict = defaultdict(dict)
model_features_dict = defaultdict(dict)

for i in tqdm(range(NUM_STOCKS)):
    for j in range(i+1, NUM_STOCKS):

        ma_model = build_difference_linear_regression(log_return_df, [i, j], features, FIRST_TEST_DATE, TRAIN_LENGTH)
        ma_y, ma_pred = predict_train_difference(log_return_df, ma_model, [i, j], features, FIRST_TEST_DATE, TRAIN_LENGTH)

        if abs(ma_model.tvalues.values[0]) >= 2 or abs(ma_model.tvalues.values[len(features)]//2) >= 2:
            good_model_dict[i][j] = ma_model
            model_features_dict[i][j] = features
            model_accuracy_dict[i][j] = accuracy_score(np.sign(ma_y), np.sign(ma_pred))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_19499/832433225.py in <module>
#       6     for j in range(i+1, NUM_STOCKS):
#       7
# ----> 8         ma_model = build_difference_linear_regression(log_return_df, [i, j], features, FIRST_TEST_DATE, TRAIN_LENGTH)
#       9         ma_y, ma_pred = predict_train_difference(log_return_df, ma_model, [i, j], features, FIRST_TEST_DATE, TRAIN_LENGTH)
#      10
#
# NameError: name 'FIRST_TEST_DATE' is not defined

# %%
def build_models_for_this_period(log_return_df, test_start_date):

    good_model_dict = defaultdict(dict)
    model_accuracy_dict = defaultdict(dict)
    model_features_dict = defaultdict(dict)

    for i in range(NUM_STOCKS):
        for j in range(i+1, NUM_STOCKS):
            
            ma_model = build_difference_linear_regression(log_return_df, [i, j], features, test_start_date, TRAIN_LENGTH)
            ma_y, ma_pred = predict_train_difference(log_return_df, ma_model, [i, j], features, test_start_date, TRAIN_LENGTH)

            if abs(ma_model.tvalues.values[0]) >= 2 or abs(ma_model.tvalues.values[len(features)]//2) >= 2:
                good_model_dict[i][j] = ma_model
                model_features_dict[i][j] = features
                model_accuracy_dict[i][j] = accuracy_score(np.sign(ma_y), np.sign(ma_pred))

    final_model_dict = defaultdict(dict)

    for stock_i in model_accuracy_dict:
        top_10 = sorted(model_accuracy_dict[stock_i].items(), key=lambda x: x[1], reverse=True)
        for stock_j, score in top_10:
            
            if stock_j in good_model_dict[stock_i]: # Todo: in future take average, or take average of votes?
                final_model_dict[stock_i][stock_j] = good_model_dict[stock_i][stock_j]

    return final_model_dict, model_features_dict

# %%
def getMyPosition(prcSoFar):
    
    global currentPos, final_model_dict, model_features_dict, no_signal, total_signals, test_start_date

    
    if prcSoFar.shape[1] == START_DATE+250: # last day don't make any new positions
        return currentPos

    log_return_df = feature_engineer(prcSoFar)

    # retrain model every 50 days
    if prcSoFar.shape[1] % TEST_LENGTH == 0:
        test_start_date = prcSoFar.shape[1]

        final_model_dict, model_features_dict = build_models_for_this_period(log_return_df, test_start_date)
    
    signal = np.zeros(50)

    # make predictions
    for stock_i in final_model_dict:
        for stock_j in final_model_dict[stock_i]:
            
            stock_i_j_prediction = inference_difference_linear_regression(log_return_df,
                                    final_model_dict[stock_i][stock_j],
                                    [stock_i,
                                    stock_j],
                                    model_features_dict[stock_i][stock_j],
                                    test_start_date,
                                    TRAIN_LENGTH)

            if stock_i_j_prediction > 0: 
                signal[stock_i] += 1
                signal[stock_j] -= 1
            elif stock_i_j_prediction < 0:
                signal[stock_i] -= 1
                signal[stock_j] += 1
     

    for stock_i in final_model_dict:
        if signal[stock_i] > 0:
            currentPos[stock_i] += 1000/prcSoFar[stock_i, -1]
        elif signal[stock_i] < -0:
            currentPos[stock_i] -= 1000/prcSoFar[stock_i, -1]
        
    return currentPos
